# %%
import pandas as pd
import re

# %%
# Get story text
with open('expensivelessons.txt') as f:
  sentences = f.read().splitlines()

words = []
for i in range(len(sentences)):
  for word in sentences[i].split(" "):
    word_cleaned = re.sub(r'[\",\(,\),\,,\;,\.,\?,\!,\:]', '', word)
    words.append({
      "sentence": i,
      "word": word_cleaned,
      "word_length": len(word_cleaned)
    })

# %%
# append story text to eyelink file
eyelink_data = pd.read_csv('ia_files/2_EL.txt', sep='\t')
eyelink_data.head()
words_df = pd.DataFrame(words)
words_df.head()
eyelink_with_text = pd.concat([words_df, eyelink_data], axis=1)
eyelink_with_text.head(20)
# Out:
# /var/folders/0t/rs4xlk9945xdd3cxy6yc9j340000gq/T/ipykernel_38973/594582580.py:2: DtypeWarning: Columns (45,58,59,60,65,66,67,68,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,134,135,136,137,138,139,140,141,142,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,315,316,317,318,461,474,475,476,481,482,483,484,522,523,524,525,526,527,528,529,530,531,532,533,534,535,536,537,538,539,540,541,542,543,544,545,546,547,548,549,550,551,552,553,554,555,556,557,558,559,560,561,562,563,564,565,566,567,568,569,570,571,572,573,574,575,576,577,578,579,580,581,582,583,584,585,586,587,588,589,590,591,592,593,594,595,596,597,598,599,600,601,602,603,604,605,606,607,608,609,610,611,612,613,614,615,616,617,618,619,620,621,622,623,624,625,626,627,628,629,630,631,632,633,634,635,636,637,638,639,640,641,642,643,644,645,646,647,648,649,650,651,652,653,654,655,656,657,658,659,660,661,662,663,664,665,666,667,668,669,670,671,672,673,674,675,676,677,678,679,680,681,682,683,684,685,686,687,688,689,690,691,692,693,694,695,696,697,698,699,700,701,702,703,704,705,706,707,708,709,710,711,712,713,714,715,716,717,718,719,720,721,722,723,724,725,726,727,731,732,733,734) have mixed types. Specify dtype option on import or set low_memory=False.
#   eyelink_data = pd.read_csv('ia_files/2_EL.txt', sep='\t')
#     sentence           word  word_length  RECORDING_SESSION_LABEL  \
# 0          0            For            3                        2
# 1          0              a            1                        2
# 2          0     cultivated           10                        2
# 3          0            man            3                        2
# 4          0             to            2                        2
# 5          0             be            2                        2
# 6          0       ignorant            8                        2
# 7          0             of            2                        2
# 8          0        foreign            7                        2
# 9          0      languages            9                        2
# 10         0             is            2                        2
# 11         0              a            1                        2
# 12         0          great            5                        2
# 13         0  inconvenience           13                        2
# 14         1        Vorotov            7                        2
# 15         1         became            6                        2
# 16         1        acutely            7                        2
# 17         1      conscious            9                        2
# 18         1             of            2                        2
# 19         1             it            2                        2
#
#     TRIAL_INDEX DATA_FILE EYE_USED GROUPING_VARIABLES  IA_AREA  \
# 0             6     2.edf     LEFT       CURRENT_PAGE   1880.0
# 1             6     2.edf     LEFT       CURRENT_PAGE    740.0
# 2             6     2.edf     LEFT       CURRENT_PAGE   4580.0
# 3             6     2.edf     LEFT       CURRENT_PAGE   2200.0
# 4             6     2.edf     LEFT       CURRENT_PAGE   1220.0
# 5             6     2.edf     LEFT       CURRENT_PAGE   1400.0
# 6             6     2.edf     LEFT       CURRENT_PAGE   4020.0
# 7             6     2.edf     LEFT       CURRENT_PAGE   1160.0
# 8             6     2.edf     LEFT       CURRENT_PAGE   3440.0
# 9             6     2.edf     LEFT       CURRENT_PAGE   4780.0
# 10            6     2.edf     LEFT       CURRENT_PAGE    940.0
# 11            6     2.edf     LEFT       CURRENT_PAGE    780.0
# 12            6     2.edf     LEFT       CURRENT_PAGE   2600.0
# 13            6     2.edf     LEFT       CURRENT_PAGE   6740.0
# 14            6     2.edf     LEFT       CURRENT_PAGE   3820.0
# 15            6     2.edf     LEFT       CURRENT_PAGE   3720.0
# 16            6     2.edf     LEFT       CURRENT_PAGE   3400.0
# 17            6     2.edf     LEFT       CURRENT_PAGE   4580.0
# 18            6     2.edf     LEFT       CURRENT_PAGE   1220.0
# 19            6     2.edf     LEFT       CURRENT_PAGE    800.0
#
#    IA_AVERAGE_FIX_PUPIL_SIZE  ...         TRIAL_LABEL  TRIAL_START_TIME  \
# 0                     149.00  ...  Trial: 1_Segment_5            231097
# 1                          .  ...  Trial: 1_Segment_5            231097
# 2                     170.40  ...  Trial: 1_Segment_5            231097
# 3                     172.00  ...  Trial: 1_Segment_5            231097
# 4                     191.00  ...  Trial: 1_Segment_5            231097
# 5                          .  ...  Trial: 1_Segment_5            231097
# 6                     175.00  ...  Trial: 1_Segment_5            231097
# 7                          .  ...  Trial: 1_Segment_5            231097
# 8                     165.00  ...  Trial: 1_Segment_5            231097
# 9                     166.00  ...  Trial: 1_Segment_5            231097
# 10                         .  ...  Trial: 1_Segment_5            231097
# 11                         .  ...  Trial: 1_Segment_5            231097
# 12                         .  ...  Trial: 1_Segment_5            231097
# 13                         .  ...  Trial: 1_Segment_5            231097
# 14                         .  ...  Trial: 1_Segment_5            231097
# 15                         .  ...  Trial: 1_Segment_5            231097
# 16                         .  ...  Trial: 1_Segment_5            231097
# 17                    138.00  ...  Trial: 1_Segment_5            231097
# 18                         .  ...  Trial: 1_Segment_5            231097
# 19                         .  ...  Trial: 1_Segment_5            231097
#
#     TRIAL_TOTAL_VISITED_IA_COUNT  \
# 0                            102
# 1                            102
# 2                            102
# 3                            102
# 4                            102
# 5                            102
# 6                            102
# 7                            102
# 8                            102
# 9                            102
# 10                           102
# 11                           102
# 12                           102
# 13                           102
# 14                           102
# 15                           102
# 16                           102
# 17                           102
# 18                           102
# 19                           102
#
#                                          CURRENT_PAGE PAGE_HEIGHT PAGE_VISIT  \
# 0   http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 1   http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 2   http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 3   http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 4   http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 5   http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 6   http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 7   http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 8   http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 9   http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 10  http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 11  http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 12  http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 13  http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 14  http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 15  http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 16  http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 17  http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 18  http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
# 19  http://cs-u-grace.cs.umn.edu/read/expensiveles...         964          1
#
#    PAGE_VISIT_DURATION PAGE_WIDTH SEGMENT_INDEX      SEGMENT_PARENT_TRIAL
# 0                79330       1680             5  2: Trial: 1 -  Segmented
# 1                79330       1680             5  2: Trial: 1 -  Segmented
# 2                79330       1680             5  2: Trial: 1 -  Segmented
# 3                79330       1680             5  2: Trial: 1 -  Segmented
# 4                79330       1680             5  2: Trial: 1 -  Segmented
# 5                79330       1680             5  2: Trial: 1 -  Segmented
# 6                79330       1680             5  2: Trial: 1 -  Segmented
# 7                79330       1680             5  2: Trial: 1 -  Segmented
# 8                79330       1680             5  2: Trial: 1 -  Segmented
# 9                79330       1680             5  2: Trial: 1 -  Segmented
# 10               79330       1680             5  2: Trial: 1 -  Segmented
# 11               79330       1680             5  2: Trial: 1 -  Segmented
# 12               79330       1680             5  2: Trial: 1 -  Segmented
# 13               79330       1680             5  2: Trial: 1 -  Segmented
# 14               79330       1680             5  2: Trial: 1 -  Segmented
# 15               79330       1680             5  2: Trial: 1 -  Segmented
# 16               79330       1680             5  2: Trial: 1 -  Segmented
# 17               79330       1680             5  2: Trial: 1 -  Segmented
# 18               79330       1680             5  2: Trial: 1 -  Segmented
# 19               79330       1680             5  2: Trial: 1 -  Segmented
#
# [20 rows x 969 columns]
